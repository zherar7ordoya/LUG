-- %% [markdown]
-- # [BD_Ejemplo_Null]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [BD_Ejemplo_Null]    Script Date: 26/4/2021 10:03:34 ******/
CREATE DATABASE [BD_Ejemplo_Null]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'BD_Ejemplo_Null', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS02\MSSQL\DATA\BD_Ejemplo_Null.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'BD_Ejemplo_Null_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS02\MSSQL\DATA\BD_Ejemplo_Null_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [BD_Ejemplo_Null] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [BD_Ejemplo_Null].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [BD_Ejemplo_Null] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [BD_Ejemplo_Null] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [BD_Ejemplo_Null] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [BD_Ejemplo_Null] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [BD_Ejemplo_Null] SET ARITHABORT OFF 
GO
ALTER DATABASE [BD_Ejemplo_Null] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [BD_Ejemplo_Null] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [BD_Ejemplo_Null] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [BD_Ejemplo_Null] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [BD_Ejemplo_Null] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [BD_Ejemplo_Null] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [BD_Ejemplo_Null] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [BD_Ejemplo_Null] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [BD_Ejemplo_Null] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [BD_Ejemplo_Null] SET  DISABLE_BROKER 
GO
ALTER DATABASE [BD_Ejemplo_Null] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [BD_Ejemplo_Null] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [BD_Ejemplo_Null] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [BD_Ejemplo_Null] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [BD_Ejemplo_Null] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [BD_Ejemplo_Null] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [BD_Ejemplo_Null] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [BD_Ejemplo_Null] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [BD_Ejemplo_Null] SET  MULTI_USER 
GO
ALTER DATABASE [BD_Ejemplo_Null] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [BD_Ejemplo_Null] SET DB_CHAINING OFF 
GO
ALTER DATABASE [BD_Ejemplo_Null] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [BD_Ejemplo_Null] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [BD_Ejemplo_Null] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [BD_Ejemplo_Null] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [BD_Ejemplo_Null] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[Persona]

-- %%
USE [BD_Ejemplo_Null]
GO

-- %%
/****** Object:  Table [dbo].[Persona]    Script Date: 26/4/2021 10:03:34 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Persona](
	[Codigo] [int] IDENTITY(1,1) NOT NULL,
	[Nombre] [nchar](20) NOT NULL,
	[Apellido] [nchar](20) NOT NULL,
	[mail] [nchar](30) NULL,
	[password] [nchar](30) NULL,
 CONSTRAINT [PK_Persona] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [BD_Ejemplo_Null]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [BD_Ejemplo_Null] SET  READ_WRITE 
GO
